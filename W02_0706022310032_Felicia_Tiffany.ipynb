# %% [markdown]
# Felicia Tiffany - 0706022310032

# %% [markdown]
# **Part A – Data Preprocessing**

# %%
import pandas as pd

# Load the dataset
# Download the CSV file from the URL
url = "https://raw.githubusercontent.com/NathaliaMinoque/datasets/refs/heads/main/jabodetabek_house_price.csv"
df = pd.read_csv(url, sep=',')

df.head()
# Out:
#                                                  url   price_in_rp  \
# 0  https://www.rumah123.com/properti/bekasi/hos11...  2.990000e+09
# 1  https://www.rumah123.com/properti/bekasi/hos10...  1.270000e+09
# 2  https://www.rumah123.com/properti/bekasi/hos10...  1.950000e+09
# 3  https://www.rumah123.com/properti/bekasi/hos10...  3.300000e+09
# 4  https://www.rumah123.com/properti/bekasi/hos10...  4.500000e+09
#
#                                                title  \
# 0  Rumah cantik Sumarecon Bekasi\nLingkungan asri...
# 1          Rumah Kekinian, Magenta Summarecon Bekasi
# 2  Rumah Cantik 2 Lantai Cluster Bluebell Summare...
# 3  Rumah Mewah 2Lantai L10x18 C di Cluster VERNON...
# 4  Rumah Hoek di Cluster Maple Summarecon Bekasi,...
#
#                      address           district     city       lat  \
# 0  Summarecon Bekasi, Bekasi  Summarecon Bekasi   Bekasi -6.223945
# 1  Summarecon Bekasi, Bekasi  Summarecon Bekasi   Bekasi -6.223945
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3553 entries, 0 to 3552
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   url                   3553 non-null   object
#  1   price_in_rp           3553 non-null   float64
#  2   title                 3553 non-null   object
#  3   address               3553 non-null   object
#  4   district              3553 non-null   object
#  5   city                  3553 non-null   object
#  6   lat                   3553 non-null   float64
#  7   long                  3553 non-null   float64
#  8   facilities            3553 non-null   object
#  9   property_type         3552 non-null   object
#  10  ads_id                3549 non-null   object
#  11  bedrooms              3519 non-null   float64
#  12  bathrooms             3524 non-null   float64
#  13  land_size_m2          3551 non-null   float64
# ...

# %%
df.describe()
# Out:
#         price_in_rp          lat         long     bedrooms    bathrooms  \
# count  3.553000e+03  3553.000000  3553.000000  3519.000000  3524.000000
# mean   4.191685e+09    -6.324721   106.792881     3.326513     2.624858
# std    1.375067e+10     0.129245     0.172159     2.672148     2.696497
# min    4.200000e+07    -6.894828   106.402315     1.000000     1.000000
# 25%    8.000000e+08    -6.397933   106.687295     2.000000     2.000000
# 50%    1.500000e+09    -6.300733   106.799954     3.000000     2.000000
# 75%    3.590000e+09    -6.231754   106.874766     4.000000     3.000000
# max    5.800000e+11    -6.102478   109.771691    99.000000    99.000000
#
#        land_size_m2  building_size_m2     carports  maid_bedrooms  \
# count   3551.000000       3551.000000  3553.000000    3553.000000
# mean     204.806815        186.587440     1.197861       0.496482
# std      402.127746        248.443471     1.114996       0.685723
# ...

# %% [markdown]
# Key Findings :
# 1. Median harga properti (price_in_rp) sekitar 1,5 miliar, tetapi harga rata rata properti merupakan 4,19 miliar. Hal ini terindikasi adanya outlier. Nilai minimum adalah 42 juta yang terindikasi harga tidak realistis, outlier atau salah ketik.
# 2. median luas tanah dengan median luas bangunan proposional, tetapi ada properti yang berpotensi outlier dengan luas tanah 8000 m^2 dan luas bangunan 6000^2.
# 3. rata rata kamar tidur dan kamar mandi masuk akal di angka 3 dan 2. Ada juga yang sampai 99 kamar tidur dan 99 kamar mandi yang kemungkinan outlier dan berupa hotel.
# 4. tahun dibangun rata rata tahun 2018 dengan umur bangunan rata rata 3 tahun, tetapi ada kesalahan ketik tahun dibangun ada data 2052.
# 5. rata rata dan median maid_bedrooms merupakan 0, artinya mayoritas rumah tidak memiliki kamar tidur untuk ART
# 6. rata rata setiap rumah memiliki 1 carports saja, tetapi ada data yang menunjukkan bahwa ada yang memiliki 15 carports. Diasumsikan bahwa rumah mewah atau hotel.

# %%
# Calculate null values and percentage
null_counts = df.isnull().sum()
null_percentages = (null_counts / len(df)) * 100

# Create a DataFrame for columns with null values
null_df = pd.DataFrame({'Null Count': null_counts, 'Null Percentage': null_percentages})

# Filter for columns with null values
null_df = null_df[null_df['Null Count'] > 0]


# Format the percentage with two decimal places and % symbol
null_df['Null Percentage'] = null_df['Null Percentage'].map('{:.2f}%'.format)


null_df
# Out:
#                       Null Count Null Percentage
# property_type                  1           0.03%
# ads_id                         4           0.11%
# bedrooms                      34           0.96%
# bathrooms                     29           0.82%
# land_size_m2                   2           0.06%
# building_size_m2               2           0.06%
# certificate                  141           3.97%
# floors                         6           0.17%
# building_age                1445          40.67%
# year_built                  1445          40.67%
# property_condition           246           6.92%
# building_orientation        1647          46.36%
# furnishing                   387          10.89%

# %% [markdown]
# Key Findings :
# 1. Missing values paling tinggi terdapat pada building_orientation, dimana berfungsi untuk menjelaskan hadap mana properti tersebut
# 2. building_age dan year_built memiliki jumlah missing values yang sama yaitu 1445, kedua kolom ini berhubungan dan missing value selalu muncul bersamaan
# 3. furnishing terdapat 10,89% missing values yang menjelaskan apakah properti tersebut furnished atau tidak furnished, mirip dengan property_condition dengan missing values 6.92% yang menjelaskan baru, sudah direnovasi, bagus. 2 kolom ini mirip karena tujuan dan datanya mirip
# 4. terdapat 141 missing values di kolom certificate yang penting diketahui oleh calon pembeli dan agent

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create the horizontal bar plot
plt.figure(figsize=(10, 6))  # Adjust figure size as needed
sns.barplot(x='Null Count', y=null_df.index, data=null_df, orient='h', palette='rainbow')
plt.xlabel('Number of Null Values', fontsize=12)
plt.ylabel('Columns', fontsize=12)
plt.title('Null Values per Column', fontsize=14)

# Add labels to the bars
for i, v in enumerate(null_df['Null Count']):
    plt.text(v + 1, i, str(v), color='black', va='center', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1899111875.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Null Count', y=null_df.index, data=null_df, orient='h', palette='rainbow')

# %%
# Display unique values for each column
for col in df.columns:
  print(f"Unique values for column '{col}':")
  print(df[col].unique())
  print("-" * 20)
# Out:
# Unique values for column 'url':
# ['https://www.rumah123.com/properti/bekasi/hos11360272/#qid~213b5619-a399-47b3-bfcf-faaef6b542d5'
#  'https://www.rumah123.com/properti/bekasi/hos10680347/#qid~748f5d2d-8d3a-4a4e-a1b4-37c7be7ffc25'
#  'https://www.rumah123.com/properti/bekasi/hos10685867/#qid~f6c2cf9d-44fa-4c1a-8749-8ee96b116e93'
#  ...
#  'https://www.rumah123.com/properti/tangerang/hos11359594/#qid~0d9492e8-7326-465d-85ee-e54559fedc26'
#  'https://www.rumah123.com/properti/tangerang/hos11359313/#qid~5d5b05f9-ab0d-4774-ae61-bddd6e38b7f0'
#  'https://www.rumah123.com/properti/tangerang/hos11358964/#qid~5d5b05f9-ab0d-4774-ae61-bddd6e38b7f0']
# --------------------
# Unique values for column 'price_in_rp':
# [2.99e+09 1.27e+09 1.95e+09 3.30e+09 4.50e+09 2.70e+09 2.35e+09 2.90e+09
#  2.55e+09 9.52e+08 1.80e+09 2.50e+09 5.36e+09 2.25e+09 2.45e+09 1.25e+08
#  1.98e+09 7.64e+08 2.00e+09 4.80e+08 1.90e+09 3.00e+08 5.27e+09 2.80e+09
# ...

# %%
# Handle missing values
# electricity

df["electricity"] = (
    df["electricity"]
    .astype(str)
    .str.replace("VA", "", regex=False)
    .str.replace(r"[^0-9]", "", regex=True)
)

df["electricity"] = pd.to_numeric(df["electricity"], errors="coerce")

print(df["electricity"].unique())
# Out:
# [ 4400.  2200.  3500.  1300.    nan  5500.  6600.  7700.  3300.  7600.
#  10600.   900. 47500. 11000.  8000.   450. 10000. 53000. 16500. 13200.
#  13900. 17600. 23000. 41500. 12700. 13300. 33000. 24000. 22000.  9500.]

# %%
# Handle missing values
# electricity

mask_missing = df["electricity"].isna()

median_elec = df["electricity"].median()
df["electricity"] = df["electricity"].fillna(median_elec)

print(df.loc[mask_missing, ["electricity", "building_size_m2", "bedrooms", "bathrooms", "land_size_m2"]])
# Out:
#       electricity  building_size_m2  bedrooms  bathrooms  land_size_m2
# 26         2200.0             140.0       3.0        2.0         119.0
# 29         2200.0             120.0       2.0        3.0          91.0
# 45         2200.0             105.0       4.0        3.0          84.0
# 56         2200.0              36.0       2.0        1.0          60.0
# 117        2200.0             200.0       4.0        4.0         325.0
# ...           ...               ...       ...        ...           ...
# 3443       2200.0             135.0       3.0        3.0         120.0
# 3459       2200.0              72.0       3.0        2.0          60.0
# 3493       2200.0             125.0       3.0        2.0         237.0
# 3521       2200.0              36.0       2.0        1.0          60.0
# 3530       2200.0            1046.0       5.0        4.0         801.0
#
# [294 rows x 5 columns]

# %%
# Handle missing values
# property_type use a measure of central tendency for the attribute
# memilih modus untuk mengisi missing values karena hanya ada "rumah" dan nan, serta hanya ada 1 missing values

df['property_type'].fillna(df['property_type'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-1380611144.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['property_type'].fillna(df['property_type'].mode()[0], inplace=True)

# %%
# Handle missing values
# certificate use a global constant to fill in the missing value
# karena jenis sertifikat tidak bisa di manipulasi jadi lebih baik untuk mengisinya dengan unknown

df['certificate'] = df['certificate'].fillna("unknown")

# %%
# Handle missing values
# year_built di drop
# karena memberikan informasi yang sama dengan column building_age

df = df.drop(columns=["year_built"])

# %%
# Handle missing values
# url dan ads_id di drop
# karena tidak memberikan informasi untuk visualisasi data

df = df.drop(columns=["url", "ads_id"])

# %%
# Handle missing values
# menghitung jumlah fasilitas dengan split ',' dan menggunakan "set" agar tidak ada data duplikat dihitung 2 kali

df["facilities"] = df["facilities"].apply(
    lambda x: len(set(str(x).split(","))) if pd.notna(x) else 0
)

# %% [markdown]
# **Data Binning**

# %%
# data binning untuk facilities
# agar informasi lebih mudah dibaca dengan dihitung jumlah fasilitas lalu dikelompokkan dalam data binning

df["facilities_bin"] = 0

df.loc[(df['facilities'] >= 1) & (df['facilities'] <= 5), 'facilities_bin'] = 1
df.loc[(df['facilities'] >= 6) & (df['facilities'] <= 10), 'facilities_bin'] = 2
df.loc[(df['facilities'] >= 11) & (df['facilities'] <= 15), 'facilities_bin'] = 3
df.loc[(df['facilities'] >= 16) & (df['facilities'] <= 20), 'facilities_bin'] = 4
df.loc[df['facilities'] >= 21, 'facilities_bin'] = 5

print(df[["facilities", "facilities_bin"]].head(10))
print("Unique bins:", df["facilities_bin"].unique())
# Out:
#    facilities  facilities_bin
# 0           4               1
# 1           1               1
# 2           6               2
# 3           9               2
# 4           5               1
# 5           4               1
# 6           2               1
# 7           2               1
# 8           1               1
# 9           2               1
# Unique bins: [1 2 3 4 5]

# %%
# Handle missing values
# building_orientation di drop
# karena jumlah missing values hampir 50% dantidak bisa dimanipulasi jadi lebih baik di drop

df = df.drop(columns=["building_orientation"])

# %%
# Handle missing values
# floors use a measure of central tendency for the attribute
# menggunakan median karena datanya akan aman karena median mengambil nilai tengah

mask_missing = df["floors"].isna()

# hitung median
median_floors = df["floors"].median()
df["floors"] = df["floors"].fillna(median_floors)

print(df.loc[mask_missing, ["floors", "building_size_m2", "bedrooms", "bathrooms", "land_size_m2"]])
# Out:
#       floors  building_size_m2  bedrooms  bathrooms  land_size_m2
# 1800     2.0               NaN       NaN        NaN           NaN
# 1826     2.0             200.0       3.0        3.0         187.0
# 2172     2.0             600.0       3.0        3.0         250.0
# 2316     2.0             250.0       4.0        4.0         320.0
# 2922     2.0             358.0       4.0        4.0         200.0
# 2936     2.0               NaN       NaN        NaN           NaN

# %%
# Handle missing values
# Deleting row untuk data yang missing value lebih dari 6
# data tersebut missing pada kolom yang penting seperti: bedroom, bathroom, land size dan building size

# Hitung missing value per row
df['missing_count'] = df.isna().sum(axis=1)

# Drop baris dengan missing value >= 6
df = df[df['missing_count'] < 6]

# Hapus kolom bantu
df = df.drop(columns=['missing_count'])

# %%
# Handle missing values
# bedrooms use the most probable value to fill in the missing value
# karena bedrooms memiliki hubungan yang kuat antara building size, land size dan floors
from sklearn.tree import DecisionTreeRegressor
import numpy as np

features_bed = ["building_size_m2", "land_size_m2", "floors"]

mask_bed_missing = df["bedrooms"].isna()

# Train & Test
train_bed = df[df["bedrooms"].notna()]
test_bed = df[df["bedrooms"].isna()]

# Latih model & prediksi
if not test_bed.empty:
    model_bed = DecisionTreeRegressor(random_state=42)
    model_bed.fit(train_bed[features_bed], train_bed["bedrooms"])
    preds = model_bed.predict(test_bed[features_bed])
    df.loc[mask_bed_missing, "bedrooms"] = np.round(preds).astype(int)

print(df.loc[mask_bed_missing, ["bedrooms", "building_size_m2", "land_size_m2", "floors"]])
# Out:
#       bedrooms  building_size_m2  land_size_m2  floors
# 8          4.0             152.0         200.0     2.0
# 24         7.0             155.0         164.0     1.0
# 60         3.0              90.0         120.0     2.0
# 110        2.0              53.0          63.0     1.0
# 131        3.0             121.0         144.0     1.0
# 409        1.0              60.0          60.0     1.0
# 441        3.0             100.0         120.0     1.0
# 445        2.0              36.0          60.0     1.0
# 491        3.0              90.0         113.0     2.0
# 511        2.0              30.0          75.0     1.0
# 576        2.0              50.0          90.0     1.0
# 764        2.0             400.0        2916.0     3.0
# 793        2.0             400.0        2916.0     3.0
# 850        2.0             400.0        2916.0     3.0
# 973        3.0             100.0         112.0     1.0
# 990        2.0              36.0          45.0     1.0
# ...

# %%
# Handle missing values
# bathrooms use the most probable value to fill in the missing value
# karena bathrooms memiliki hubungan yang kuat antara bedrooms, building size, land size dan floors

from sklearn.tree import DecisionTreeRegressor
features_bath = ["building_size_m2", "land_size_m2", "floors", "bedrooms"]

mask_bath_missing = df["bathrooms"].isna()

# Train & Test
train_bath = df[df["bathrooms"].notna()]
test_bath = df[df["bathrooms"].isna()]

if not test_bath.empty:
    model_bath = DecisionTreeRegressor(random_state=42)
    model_bath.fit(train_bath[features_bath], train_bath["bathrooms"])
    preds = model_bath.predict(test_bath[features_bath])
    df.loc[mask_bath_missing, "bathrooms"] = np.round(preds).astype(int)

print(df.loc[mask_bath_missing, ["bathrooms", "building_size_m2", "land_size_m2", "floors", "bedrooms"]])
# Out:
#       bathrooms  building_size_m2  land_size_m2  floors  bedrooms
# 24          2.0             155.0         164.0     1.0       7.0
# 110         1.0              53.0          63.0     1.0       2.0
# 131         2.0             121.0         144.0     1.0       3.0
# 409         1.0              60.0          60.0     1.0       1.0
# 441         2.0             100.0         120.0     1.0       3.0
# 445         1.0              36.0          60.0     1.0       2.0
# 491         2.0              90.0         113.0     2.0       3.0
# 497         2.0              48.0          60.0     1.0       2.0
# 511         1.0              30.0          75.0     1.0       2.0
# 973         2.0             100.0         112.0     1.0       3.0
# 1087        3.0              80.0          82.0     1.0       3.0
# 1268        1.0              56.0         105.0     1.0       2.0
# 1536        2.0              70.0          67.0     1.0       2.0
# ...

# %%
# Handle missing values
# building_age use a measure of central tendency for the attribute
# paling cocok untuk mengisi building_age karena nilai tengah
mask_missing = df["building_age"].isna()

# hitung median
median_age = df["building_age"].median()
df["building_age"] = df["building_age"].fillna(median_age)

print(df.loc[mask_missing, ["building_age", "property_condition", "furnishing"]])
# Out:
#       building_age property_condition      furnishing
# 1              1.0              bagus             NaN
# 2              1.0              bagus     unfurnished
# 6              1.0                NaN             NaN
# 7              1.0                NaN             NaN
# 8              1.0                NaN  semi furnished
# ...            ...                ...             ...
# 3535           1.0              bagus  semi furnished
# 3536           1.0     sudah renovasi             NaN
# 3537           1.0              bagus  semi furnished
# 3538           1.0              bagus  semi furnished
# 3541           1.0              bagus  semi furnished
#
# [1444 rows x 3 columns]

# %%
# Handle missing values
# property_condition dan furnishing
# cara pertama fill the missing value manually, karena dilihat dari unique, terlihat ada value yang tertukar
# seharusnya "semi furnished" dann "unfurnished" terdapat di kolom furnishing
# dan "baru" terdapat di kolom property_condition, jadi saya menukar value dulu sebelum mengisi missing value yang lain

mask = df["property_condition"].isin(["semi furnished", "unfurnished"])

# simpan nilai yang salah
temp = df.loc[mask, "property_condition"]

# tukar: isi property_condition dengan furnishing
df.loc[mask, "property_condition"] = df.loc[mask, "furnishing"]

# isi furnishing dengan nilai yang tadinya salah
df.loc[mask, "furnishing"] = temp

# %%
df["property_condition"].isna().sum()
# Out:
# np.int64(244)

# %%
# Handle missing values
# property_condition use a measure of central tendency for the attribute
# memilih modus karena datanya kategorical

df['property_condition'].fillna(df['property_condition'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-4170973342.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['property_condition'].fillna(df['property_condition'].mode()[0], inplace=True)

# %%
df["furnishing"].isna().sum()
# Out:
# np.int64(385)

# %%
# Handle missing values
# furnishing use a measure of central tendency for the attribute
# memilih modus karena datanya kategorical

df['furnishing'].fillna(df['furnishing'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-756329425.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['furnishing'].fillna(df['furnishing'].mode()[0], inplace=True)

# %%
# binning price_in_rp
# karena banyak sekali unique value jadi lebih baik dikelompokkan ke dalam range tertentu
# saya memilih kategori ini karena harga kelompok yang realistis dan mudah dipahami audiens
# kelompok ini biasa digunakan oleh developer, agen dan bank

df["price_bin"] = 0

bins = [0, 5e8, 1e9, 5e9, 2e10, np.inf]
labels = ["<500 Jt", "500 Jt–1 M", "1–5 M", "5–20 M", ">20 M"]

df["price_bin"] = pd.cut(df["price_in_rp"], bins=bins, labels=labels, right=True)

print(df[["price_in_rp", "price_bin"]].head(10))
# Out:
#     price_in_rp price_bin
# 0  2.990000e+09     1–5 M
# 1  1.270000e+09     1–5 M
# 2  1.950000e+09     1–5 M
# 3  3.300000e+09     1–5 M
# 4  4.500000e+09     1–5 M
# 5  2.700000e+09     1–5 M
# 6  2.350000e+09     1–5 M
# 7  4.500000e+09     1–5 M
# 8  2.900000e+09     1–5 M
# 9  2.700000e+09     1–5 M

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3551 entries, 0 to 3552
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   price_in_rp         3551 non-null   float64
#  1   title               3551 non-null   object
#  2   address             3551 non-null   object
#  3   district            3551 non-null   object
#  4   city                3551 non-null   object
#  5   lat                 3551 non-null   float64
#  6   long                3551 non-null   float64
#  7   facilities          3551 non-null   int64
#  8   property_type       3551 non-null   object
#  9   bedrooms            3551 non-null   float64
#  10  bathrooms           3551 non-null   float64
#  11  land_size_m2        3551 non-null   float64
#  12  building_size_m2    3551 non-null   float64
#  13  carports            3551 non-null   float64
#  14  certificate         3551 non-null   object
# ...

# %% [markdown]
# **Outlier**

# %%
# Boxplot for 'Bedrooms'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['bedrooms'])
plt.title('Boxplot of bedrooms')
plt.xlabel('bedrooms')
plt.show()

# Boxplot for 'Bathrooms'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['bathrooms'])
plt.title('Boxplot of bathrooms')
plt.xlabel('bathrooms')
plt.show()

# Boxplot for 'Land Size'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['land_size_m2'])
plt.title('Land Size (m2)')
plt.xlabel('land_size_m2')
plt.show()

# Boxplot for 'Building Size'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['building_size_m2'])
plt.title('Building Size (m2)')
plt.xlabel('building_size_m2')
plt.show()

# %% [markdown]
# Insights :
# - pada kamar tidur mayoritas properti memiliki kurang dari 10 kamar tidur, tetapi di boxplot ini terdapat banyak sekali outlier bahkan sampai 100 kamar, kemungkinan hotel / koskosan
# - pada kamar mandi mayoritas properti memiliki kurang dari 10, sama juga dengan kamar tidur, kamar mandi memiliki banyak outlier dan ada yang sampai 100 kamar tidur.
# - pada land size, mayoritas land size kurang dari 500 m"2, tetapi ada banyak sekali outlier sampai tidak kelihatan median dari daata tersebut, outlier sampai 8000 m"2
# - pada building size, median juga tidak terlihat karena banyak terdapat outlier yang sampai 6000 m"2

# %%
# Keep only Luas Bangunan <= 750
df = df[df['building_size_m2'] <= 750]

# Boxplot for 'Bedrooms'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['bedrooms'])
plt.title('Boxplot of bedrooms')
plt.xlabel('bedrooms')
plt.show()

# Boxplot for 'Bathrooms'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['bathrooms'])
plt.title('Boxplot of bathrooms')
plt.xlabel('bathrooms')
plt.show()

# Boxplot for 'Land Size'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['land_size_m2'])
plt.title('Land Size (m2)')
plt.xlabel('land_size_m2')
plt.show()

# Boxplot for 'Building Size'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['building_size_m2'])
plt.title('Building Size (m2)')
plt.xlabel('building_size_m2')
plt.show()

# %% [markdown]
# Insights :
# - mengerucutkan data dengan mengambil building size <= 750 m^2 karena lebih realistis untuk memisahkan outlier sehingga distribusi data lebih seimbang.
# - sudah terlihat median dari bedrooms yaitu 3-4 kamar, tetapi masih ada outlier
# - untuk bathrooms dan building size, median tetap tidak terlihat karena masih memiliki banyak outliers
# - pada land size, masih terlihat outliers ekstrim yaitu diatas 1000 m^2
# - pada building size terlihat bahwa median ada di angka 100.

# %%
# Keep only Luas Tanah <= 500
df = df[df['land_size_m2'] <= 500]

# Boxplot for 'Bedrooms'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['bedrooms'])
plt.title('Boxplot of bedrooms')
plt.xlabel('bedrooms')
plt.show()

# Boxplot for 'Bathrooms'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['bathrooms'])
plt.title('Boxplot of bathrooms')
plt.xlabel('bathrooms')
plt.show()

# Boxplot for 'Land Size'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['land_size_m2'])
plt.title('Land Size (m2)')
plt.xlabel('land_size_m2')
plt.show()

# Boxplot for 'Building Size'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['building_size_m2'])
plt.title('Building Size (m2)')
plt.xlabel('building_size_m2')
plt.show()

# %% [markdown]
# Insights :
# - ketika sudah diberi batas building size, masih terlihat banyak outliers, maka sekarang diberikan batas land size <= 500 m^2 untuk mengerucutkan data agar mengurangi outliers dan agar luas tanah lebih realistis kepada mayoritas masyarakat
# - terlihat bahwa outliers pada data building size dan land size berkurang dan tidak terlalu condong ke kanan seperti sebelumnya
# - pada kamar mandi umumnya ada 1-3 kamar mandi, tetapi masih ada outliers yang sampai 14 kamar mandi yang pasti tidak realistis untuk seukuran rumah
# - terdapat juga outliers yang tidak masuk akal di bedrooms yaitu mencapai 35 rumah

# %%
# Keep only Jumlah Kamar Tidur <= 10
df = df[df['bedrooms'] <= 10]

# Boxplot for 'Bedrooms'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['bedrooms'])
plt.title('Boxplot of bedrooms')
plt.xlabel('bedrooms')
plt.show()

# Boxplot for 'Bathrooms'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['bathrooms'])
plt.title('Boxplot of bathrooms')
plt.xlabel('bathrooms')
plt.show()

# Boxplot for 'Land Size'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['land_size_m2'])
plt.title('Land Size (m2)')
plt.xlabel('land_size_m2')
plt.show()

# Boxplot for 'Building Size'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['building_size_m2'])
plt.title('Building Size (m2)')
plt.xlabel('building_size_m2')
plt.show()

# %% [markdown]
# Insights :
# - karena tadi masih ada outliers yang banyak di bedrooms dan bathrooms, kali ini memberikan batas di bedrooms <= 10 untuk mengurangi data dengan outliers
# - hasilnya, boxplot bedrooms lebih mudah dilihat dan outliers sudah teratasi tidak terlalu banyak seperti diawal

# %%
# Keep only Jumlah Kamar Mandi <= 5
df = df[df['bathrooms'] <= 5]

# Boxplot for 'Bedrooms'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['bedrooms'])
plt.title('Boxplot of bedrooms')
plt.xlabel('bedrooms')
plt.show()

# Boxplot for 'Bathrooms'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['bathrooms'])
plt.title('Boxplot of bathrooms')
plt.xlabel('bathrooms')
plt.show()

# Boxplot for 'Land Size'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['land_size_m2'])
plt.title('Land Size (m2)')
plt.xlabel('land_size_m2')
plt.show()

# Boxplot for 'Building Size'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['building_size_m2'])
plt.title('Building Size (m2)')
plt.xlabel('building_size_m2')
plt.show()

# %% [markdown]
# Insights : pada boxplot tadi, tetap terlihat ada outliers sampai 10 kamar mandi yang kurang realistis jika disebut rumah, maka dikerucutkan lagi sampai bathrooms <= 5 agar mengurangi outliers

# %%
# Boxplot for 'garages'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['garages'])
plt.title('garages')
plt.xlabel('garages')
plt.show()

# Boxplot for 'building_age'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['building_age'])
plt.title('building_age')
plt.xlabel('building_age')
plt.show()

# %% [markdown]
# Insights : rentang umum garasi ada dari 0-1 garasi, terdapat outliers sampai 6 garasi yang kemungkinan rumah mewah, hotel atau villa. rentang building age sekitar 0-5 tahun, tetapi sangat banyak outliers sampai 50 tahun yang artinya luas properti ini sudah sangat tua.

# %%
# Keep only building_age <= 20
df = df[df['building_age'] <= 20]

# Boxplot for 'garages'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['garages'])
plt.title('garages')
plt.xlabel('garages')
plt.show()

# Boxplot for 'building_age'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['building_age'])
plt.title('building_age')
plt.xlabel('building_age')
plt.show()

# %% [markdown]
# Insights : membuat batas building age <= 20 tahun membuat boxplot mengurangi outliers yang valuenya tidak realistis, yaitu 30 - 50 tahun. Mayoritas properti relatif baru yang seusia untuk analisis pasar terkini

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3195 entries, 0 to 3552
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   price_in_rp         3195 non-null   float64
#  1   title               3195 non-null   object
#  2   address             3195 non-null   object
#  3   district            3195 non-null   object
#  4   city                3195 non-null   object
#  5   lat                 3195 non-null   float64
#  6   long                3195 non-null   float64
#  7   facilities          3195 non-null   int64
#  8   property_type       3195 non-null   object
#  9   bedrooms            3195 non-null   float64
#  10  bathrooms           3195 non-null   float64
#  11  land_size_m2        3195 non-null   float64
#  12  building_size_m2    3195 non-null   float64
#  13  carports            3195 non-null   float64
#  14  certificate         3195 non-null   object
# ...

# %% [markdown]
# **Exploratory Data Analysis (EDA)**

# %%
import matplotlib.pyplot as plt

# hitung frekuensi tiap kategori
fac_counts = df['facilities_bin'].value_counts().sort_index()

# mapping kategori ke label teks
labels = {
    1: "1–5 fasilitas",
    2: "6–10 fasilitas",
    3: "11–15 fasilitas",
    4: "16–20 fasilitas",
    5: "≥ 21 fasilitas"
}

plt.figure(figsize=(8, 5))
fac_counts.plot(kind='bar')


# ganti xtick label sesuai mapping
plt.xticks(range(len(fac_counts)), [labels[idx] for idx in fac_counts.index], rotation=0)

for i, count in enumerate(fac_counts):
    plt.text(i, count + 1, str(count), ha='center', va='bottom')

plt.title('Bar Plot of Facilities')
plt.xlabel('Jumlah Fasilitas (Kategori)')
plt.ylabel('Frekuensi Properti')
plt.tight_layout()
plt.show()

# %% [markdown]
# Insights : semakin banyak fasilitas yang tersedia, semakin sedikit jumlah properti yang ditawarkan. Mayoritas sejumlah 1755 properti hanya memiliki 1-5 fasilitas.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.scatterplot(x='land_size_m2', y='building_size_m2', data=df)
plt.title('Scatter Plot of Luas Tanah vs Luas Bangunan')
plt.xlabel('Luas Tanah (m2)')

plt.ylabel('Luas Bangunan (m2)')
plt.show()

# %% [markdown]
# Insights : Semakin luas tanahnya semakin besar luas bangunan, ini adalah hubungan yang positif. Distribusinya terdapat di bawah kiri yang artinya mayoritas properti memikili luas tanah dan luas bangunan yang relatif kecil-menengah

# %%
import matplotlib.pyplot as plt

price_counts = df["price_bin"].value_counts().sort_index()

# Pie chart
plt.figure(figsize=(7,7))
plt.pie(
    price_counts,
    labels=price_counts.index,
    autopct='%1.1f%%',   # tampilkan persentase
    startangle=140,
    colors=["#4CAF50", "#2196F3", "#FFC107", "#FF5722", "#9C27B0"]
)

plt.title("Distribusi Harga Properti (Rp)")
plt.tight_layout()
plt.show()

# %% [markdown]
# Insights : mayoritas properti sebanyak 52.4 % dijual dengan harga 1-5 miliar, dibawahnya sebanyak 26,5% dijual dengan 500 juta - 1 M dengan jumlah yang lebih kecil. Distribusi harga sangat condong ke segmen menengah, sesuai dengan tren pasar perumahan Indonesia yang pastinya demand tertinggi ada di kelas menengah

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.select_dtypes(include=['float64', 'int64']).corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Numerical Variables')
plt.show()

# %% [markdown]
# Insights :
# - Dari heatmap diatas, korelasi kuat yang positif adalah land size dan building size sebanyak 0.79, karena semakin luas tanah, cenderung semakin luas bangunannya.
# - korelasi kuat yang positif ada pada bedrooms dan bathrooms sebanyak 0.73, karena biasanya banyak kamar tidur kurang lebih sama dengan banyak kamar mandi.
# - kolerasi kuat yang positif lainnya ada pada bedrooms dan building size sebanyak 0.65, karena rumah yang besar cenderung memiliki kamar tidur yang banyak
# - kolerasi kuat yang positif lainnya adalah maid bedrooms dan maid bathrooms sebanyak 0.76, karena properti yang memiliki kamar tidur pembantu cenderung memiliki kamar mandi pembantu
# - building age memiliki kolerasi yang lemah dengan variabel lain, karena umur bangunan tidak menentukan ukuran, jumlah kamar, atau harga dan lain sebagainya.
